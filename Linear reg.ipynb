# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('Linear Regression.csv')
df.head(50)
# Out:
#     cgpa    package
# 0    1.0   3.888889
# 1   12.0   4.555556
# 2   30.0   5.222222
# 3   19.0   5.888889
# 4   24.0   6.555556
# 5   30.0   7.222222
# 6   32.0   7.888889
# 7   22.0   8.555556
# 8   45.0   9.222222
# 9   60.0   9.888889
# 10  55.0  10.555556
# 11  61.0  11.222222
# 12  60.0  11.888889
# 13  65.0  12.555556
# 14  15.0  13.222222
# 15  67.0  13.888889
# 16  17.0  14.555556
# 17  18.0  15.555556
# 18  19.0  16.555556
# 19  20.0  17.555556
# 20  21.0  18.555556
# 21  22.0  19.555556
# 22  23.0  20.555556
# 23  24.0  21.555556
# 24  25.0  22.555556
# 25  26.0  23.555556
# 26  27.0  24.555556
# 27  28.0  25.555556
# 28  29.0  26.555556
# 29  30.0  27.555556
# 30  31.0  28.555556
# 31  32.0  29.555556
# 32  33.0  30.555556
# 33  34.0  31.555556
# 34  35.0  32.555556
# 35  36.0  33.555556
# 36  37.0  27.888889
# 37  38.0  28.555556
# 38  39.0  29.222222
# 39  40.0  29.888889
# 40  41.0  30.555556
# 41  42.0  31.222222
# 42  43.0  31.888889
# 43  44.0  32.555556
# ...

# %%
sns.scatterplot(x='cgpa',y='package',data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x=df[['cgpa']]
x.ndim     #no of dimention
# Out:
# 2

# %%
x=df[['cgpa']] #independent var should be two-d
y=df['package']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=40)

# %%
from sklearn.linear_model import LinearRegression

# %%
x=4

# %%
#training process
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 95.72126540948783

# %%
lr.predict([[1]])
# Out:
# C:\Users\rajpr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8.52324191])

# %%
lr.coef_   #(m=cofficient) from y= mx+c
# Out:
# array([0.62575041])

# %%
lr.intercept_   #(c=intercept)
# Out:
# 7.897491506737495

# %%
#put it into y=mx+c

0.63335873*1+6.60336639990004

#see the result .It is equal to predict value
# Out:
# 7.23672512990004

# %%
x=df[['cgpa']] #independent var should be 2-d
y=df['package']

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x='cgpa',y='package',data=df)
plt.plot(df["cgpa"],lr.predict(x), c="red")
plt.legend(["org data","predict line"])
plt.show()

# %% [markdown]
# ###
